# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.base import BaseEstimator, TransformerMixin
from CustomEncoder import FrequencyEncoder

# %%
class FrequencyEncoder(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.freq_map_ = {}

    def fit(self, X, y=None):
        X = pd.Series(X.ravel())  
        freq = X.value_counts(normalize=True)
        self.freq_map_ = freq.to_dict()
        return self

    def transform(self, X):
        X = pd.Series(X.ravel())
        return X.map(self.freq_map_).fillna(0).to_frame()
# Out:
# "'class FrequencyEncoder(BaseEstimator, TransformerMixin):\n    def __init__(self):\n        self.freq_map_ = {}\n\n    def fit(self, X, y=None):\n        X = pd.Series(X.ravel())  \n        freq = X.value_counts(normalize=True)\n        self.freq_map_ = freq.to_dict()\n        return self\n\n    def transform(self, X):\n        X = pd.Series(X.ravel())\n        return X.map(self.freq_map_).fillna(0).to_frame()"

# %%
churn_pred_model=pickle.load(open('my_ml_pipeline','rb'))

# %%
churn_pred_model
# Out:
# Pipeline(steps=[('pre-processor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinal',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinal',
#                                                                    OrdinalEncoder(categories=[['Month-to-month',
#                                                                                                'One '
#                                                                                                'year',
#                                                                                                'Two '
#                                                                                                'year']]))]),
# ...

# %%
Contract='One year'
Tenure=30
InternetService='DSL'
TotalCharges=2890
PaymentMethod='Electronic check'
MonthlyCharges=95
TechSupport='Yes'

# %%
test=pd.DataFrame([[Contract,Tenure,InternetService,TotalCharges,PaymentMethod,MonthlyCharges,TechSupport]])
test.columns=['Contract','Tenure','InternetService','TotalCharges','PaymentMethod','MonthlyCharges','TechSupport']
test
# Out:
#    Contract  Tenure InternetService  TotalCharges     PaymentMethod  \
# 0  One year      30             DSL          2890  Electronic check
#
#    MonthlyCharges TechSupport
# 0              95         Yes

# %%
churn_pred_model.predict(test)
# Out:
# array(['No'], dtype=object)
